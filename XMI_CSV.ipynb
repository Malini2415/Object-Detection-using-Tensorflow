# %%
pip install pandas
# Out:
# ...
#   Using cached pytz-2019.3-py2.py3-none-any.whl (509 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
xml_to_csv(r'C:\Users\malini.d\Desktop\SOC Reports\soc\net_scholar\Train_images')
# Out:
#                                                filename  width  height  \
# 0     0_ADP AutoPay Payroll Services 9 30 2021 SOC 1...    765     990
# 1        0_ADP AutoPay Payroll Services.pdf resized.jpg    765     990
# 2                         0_ADP GETS US.pdf resized.jpg    765     990
# 3      0_ADP MAS eTime 09 30 2021 SOC 1.pdf resized.jpg    765     990
# 4                       0_ADP MAS eTime.pdf resized.jpg    765     990
# ...                                                 ...    ...     ...
# 3176        99_ADP Payroll Tax Services.pdf resized.jpg    765     990
# 3177  99_ADP SOC 1 Report - Auto Payroll Service Sys...    765     990
# 3178  99_ADP SOC 1 Report - Auto Payroll Service Sys...    765     990
# 3179               99_ADP Workforce Now.pdf resized.jpg    765     990
# 3180               99_ADP Workforce Now.pdf resized.jpg    765     990
#
#             class  xmin  ymin  xmax  ymax
# 0     Description    41   475   512   595
# ...

# %%
xml_to_csv(r'C:\Users\malini.d\Desktop\SOC Reports\soc\net_scholar\Test_images')
# Out:
#                                              filename  width  height  \
# 0   0_ADP AutoPay Payroll Services 9 30 2021 SOC 1...    765     990
# 1      0_ADP AutoPay Payroll Services.pdf resized.jpg    765     990
# 2                       0_ADP GETS US.pdf resized.jpg    765     990
# 3   1_ADP AutoPay Payroll Services 9 30 2021 SOC 1...    765     990
# 4   1_ADP AutoPay Payroll Services 9 30 2021 SOC 1...    765     990
# 5   1_ADP AutoPay Payroll Services 9 30 2021 SOC 1...    765     990
# 6   1_ADP AutoPay Payroll Services 9 30 2021 SOC 1...    765     990
# 7   1_ADP AutoPay Payroll Services 9 30 2021 SOC 1...    765     990
# 8   1_ADP AutoPay Payroll Services 9 30 2021 SOC 1...    765     990
# 9      1_ADP AutoPay Payroll Services.pdf resized.jpg    765     990
# 10     1_ADP AutoPay Payroll Services.pdf resized.jpg    765     990
# 11     1_ADP AutoPay Payroll Services.pdf resized.jpg    765     990
# 12     1_ADP AutoPay Payroll Services.pdf resized.jpg    765     990
# ...

# %%
import os
import glob
import pandas as pd
import xml.etree.ElementTree as ET


def xml_to_csv(path):
    xml_list = []
    for xml_file in glob.glob(path + '/*.xml'):
        tree = ET.parse(xml_file)
        root = tree.getroot()
        for member in root.findall('object'):
            value = (root.find('filename').text,
                     int(root.find('size')[0].text),
                     int(root.find('size')[1].text),
                     member[0].text,
                     int(member[4][0].text),
                     int(member[4][1].text),
                     int(member[4][2].text),
                     int(member[4][3].text)
                     )
            xml_list.append(value)
    column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df


def main():
    image_path = os.path.join(os.getcwd(), 'annotations')
    xml_df = xml_to_csv(image_path)
    #xml_df = xml_to_csv(r'D:\projects_python\ooops\images')
    xml_df.to_csv('train_labels.csv', index=None)
    print('Successfully converted xml to csv.')


main()
# Out:
# Successfully converted xml to csv.

# %%
file=xml_to_csv(r'C:\Users\malini.d\Desktop\SOC Reports\soc\net_scholar\Train_images')

# %%
file
# Out:
#                                                filename  width  height  \
# 0     0_ADP AutoPay Payroll Services 9 30 2021 SOC 1...    765     990
# 1        0_ADP AutoPay Payroll Services.pdf resized.jpg    765     990
# 2                         0_ADP GETS US.pdf resized.jpg    765     990
# 3      0_ADP MAS eTime 09 30 2021 SOC 1.pdf resized.jpg    765     990
# 4                       0_ADP MAS eTime.pdf resized.jpg    765     990
# ...                                                 ...    ...     ...
# 3176        99_ADP Payroll Tax Services.pdf resized.jpg    765     990
# 3177  99_ADP SOC 1 Report - Auto Payroll Service Sys...    765     990
# 3178  99_ADP SOC 1 Report - Auto Payroll Service Sys...    765     990
# 3179               99_ADP Workforce Now.pdf resized.jpg    765     990
# 3180               99_ADP Workforce Now.pdf resized.jpg    765     990
#
#             class  xmin  ymin  xmax  ymax
# 0     Description    41   475   512   595
# ...

# %%
file.to_csv(r'C:\Users\malini.d\Desktop\SOC Reports\soc\net_scholar\Train_images\train.csv')

# %%
file1=xml_to_csv(r'C:\Users\malini.d\Desktop\SOC Reports\soc\net_scholar\Test_images')

# %%
file1.to_csv(r'C:\Users\malini.d\Desktop\SOC Reports\soc\net_scholar\Test_images\test.csv')

# %%
from __future__ import division
from __future__ import print_function
from __future__ import absolute_import

import os
import io
import pandas as pd
import tensorflow.compat.v1 as tf
from PIL import Image
from utils import dataset_util
from collections import namedtuple, OrderedDict

# flags = tf.app.flags
# flags.DEFINE_string('csv_input', '', 'Path to the CSV input')
# flags.DEFINE_string('output_path', '', 'Path to output TFRecord')
# flags.DEFINE_string('image_dir', '', 'Path to images')
# FLAGS = flags.FLAGS


# TO-DO replace this with label map
def class_text_to_int(row_label):
    if row_label == 'so':
        return 1
    elif row_label == 'so_name':
        return 2
    elif row_label == 'tabel':
        return 3
    elif row_label == 'page_no':
        return 4
    elif row_label == 'scope':
        return 5
    elif row_label == 'Description':
        return 6
    elif row_label == 'opinion':
        return 7
    elif row_label == 'opinion_type':
        return 8
    elif row_label == 'Date_Report':
        return 9
    elif row_label == 'Functions':
        return 10
    elif row_label == 'soc_type':
        return 11
    elif row_label == 'soc_Report':
        return 12
    elif row_label == 'Auditor':
        return 13
    elif row_label == 'Subservice_ind':
        return 14
    elif row_label == 'complementery1':
        return 15
    elif row_label == 'complementery2':
        return 16
    elif row_label == 'p1':
        return 17
    elif row_label == 'p2':
        return 18
    elif row_label == 'table':
        return 19
    else:
        return 0


def split(df, group):
    data = namedtuple('data', ['filename', 'object'])
    gb = df.groupby(group)
    return [data(filename, gb.get_group(x)) for filename, x in zip(gb.groups.keys(), gb.groups)]


def create_tf_example(group, path):
    with tf.gfile.GFile(os.path.join(path, '{}'.format(group.filename)), 'rb') as fid:
        encoded_jpg = fid.read()
    encoded_jpg_io = io.BytesIO(encoded_jpg)
    image = Image.open(encoded_jpg_io)
    width, height = image.size

    filename = group.filename.encode('utf8')
    image_format = b'jpg'
    xmins = []
    xmaxs = []
    ymins = []
    ymaxs = []
    classes_text = []
    classes = []

    for index, row in group.object.iterrows():
        xmins.append(row['xmin'] / width)
        xmaxs.append(row['xmax'] / width)
        ymins.append(row['ymin'] / height)
        ymaxs.append(row['ymax'] / height)
        classes_text.append(row['class'].encode('utf8'))
        classes.append(class_text_to_int(row['class']))

    tf_example = tf.train.Example(features=tf.train.Features(feature={
        'image/height': dataset_util.int64_feature(height),
        'image/width': dataset_util.int64_feature(width),
        'image/filename': dataset_util.bytes_feature(filename),
        'image/source_id': dataset_util.bytes_feature(filename),
        'image/encoded': dataset_util.bytes_feature(encoded_jpg),
        'image/format': dataset_util.bytes_feature(image_format),
        'image/object/bbox/xmin': dataset_util.float_list_feature(xmins),
        'image/object/bbox/xmax': dataset_util.float_list_feature(xmaxs),
        'image/object/bbox/ymin': dataset_util.float_list_feature(ymins),
        'image/object/bbox/ymax': dataset_util.float_list_feature(ymaxs),
        'image/object/class/text': dataset_util.bytes_list_feature(classes_text),
        'image/object/class/label': dataset_util.int64_list_feature(classes),
    }))
    return tf_example


def main(_):
    writer = tf.python_io.TFRecordWriter(r"C:\Users\malini.d\Desktop\SOC Reports\soc\net_scholar\Test_images\test.record")
    path = os.path.join(r"C:\Users\malini.d\Desktop\SOC Reports\soc\net_scholar\Test_images")
    examples = pd.read_csv(r"C:\Users\malini.d\Desktop\SOC Reports\soc\net_scholar\Test_images\test.csv")
    grouped = split(examples, 'filename')
    for group in grouped:
        tf_example = create_tf_example(group, path)
        writer.write(tf_example.SerializeToString())

    writer.close()
    output_path = os.path.join(os.getcwd(),r"C:\Users\malini.d\Desktop\SOC Reports\soc\net_scholar\Test_images\test.record")
    print('Successfully created the TFRecords: {}'.format(output_path))


if __name__ == '__main__':
    tf.app.run()
# Out:
# Successfully created the TFRecords: C:\Users\malini.d\Desktop\SOC Reports\soc\net_scholar\Test_images\test.record
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %%
import tensorflow.compat.v1 as tf

# %%
print(tf.__version__)
# Out:
# 2.0.0
