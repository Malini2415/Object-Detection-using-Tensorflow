# %%
import os
from pdf2jpg import pdf2jpg

path = r'C:\Users\malini.d\Desktop\unstructuredata'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.pdf' in file:
            files.append(os.path.join(r, file))

for f in files:
    #print(f)
    inputpath =(f)
    outputpath = (r'C:\Users\malini.d\Desktop\unstructuredata')
    result = pdf2jpg.convert_pdf2jpg(inputpath, outputpath, dpi=200, pages="ALL")
    #print(result)

# %%
from PIL import Image

from resizeimage import resizeimage


with open(r'C:\Users\malini.d\Desktop\Tanveer\abc.jpg', 'r+b') as f:
    with Image.open(f) as image:
        cover = resizeimage.resize_cover(image, [300, 300])
        cover.save(r'C:\Users\malini.d\Desktop\Tanveer\test.jpeg', image.format)

# %%
import os, subprocess

pdf_dir = r'D:\projects_python\Escalon_Invoices\Escalon Invoices_source\test\png'
os.chdir(pdf_dir)

pdftoppm_path = r"D:\projects_python\poppler-0.68.0_x86\poppler-0.68.0\bin\pdftoppm.exe"
i=0
for pdf_file in os.listdir(pdf_dir):
    print(i)

    if pdf_file.endswith(".pdf"):

        subprocess.Popen('"%s" -jpg %s out' % (pdftoppm_path, pdf_file))
        i=i+1
# Out:
# 0
# 1
# 2
# 3

# %%
from pdf2image import convert_from_path, convert_from_bytes

from pdf2image.exceptions import (
    PDFInfoNotInstalledError,
    PDFPageCountError,
    PDFSyntaxError
)


import os
from pdf2image import convert_from_path

pdf_dir = r"C:\Users\malini.d\Desktop\Tanveer\Pdf"
os.chdir(pdf_dir)

for pdf_file in os.listdir(pdf_dir):
    if pdf_file.endswith(".pdf"):
        pages = convert_from_path(pdf_file, dpi=150)
        pdf_file = pdf_file[:-4]
        for page in pages:
            page.save("%s-page%d.jpeg" % (pdf_file,pages.index(page)), "JPEG")

# %%
input1

# %%
import shutil
import os

source = r'D:\projects_python\Escalon_Invoices\images'
dest1 = r'D:\projects_python\Escalon_Invoices\all_img'

i=0
for root,subdirs,files in os.walk(source):
    print(i)
    #print('root',root)
    #print('subdirs',subdirs)
    #print('files',files)
    for file in files:
        path=os.path.join(root,file)
        shutil.move(path,dest1)
        i=i+1
# Out:
# 0
# 0
# 1
# 2
# 3
# 4
# 5
# 8
# 10
# 25
# 26
# 27
# 28
# 29
# 31
# 33
# 34
# 35
# 44
# 49
# 50
# 51
# 52
# 53
# 55
# 56
# 59
# 60
# 61
# 62
# 66
# 67
# 68
# 69
# 72
# 73
# 74
# 75
# 78
# 79
# 81
# 82
# 83
# 89
# 90
# 91
# 92
# 93
# 95
# 96
# 102
# 103
# 104
# 105
# 107
# 108
# 109
# 110
# 112
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 125
# 126
# 127
# 132
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 151
# 152
# 181
# 188
# 189
# 191
# 192
# 193
# 194
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 208
# 209
# 210
# 212
# 213
# 215
# 216
# 220
# 221
# 222
# 223
# 224
# 227
# 231
# 232
# 233
# 234
# 237
# 238
# 240
# 241
# 242
# 243
# 244
# 248
# 251
# 252
# 253
# 254
# 256
# 257
# 258
# 259
# 261
# 269
# 270
# 271
# 273
# 274
# 275
# 276
# 280
# 281
# 282
# 283
# 284
# 287
# 288
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 328
# 329
# 330
# 331
# 332
# 333
# ...

# %%
path = r'D:\projects_python\Escalon_Invoices\\all_img'
i = 0
for filename in os.listdir(path):
    os.rename(os.path.join(path,filename), os.path.join(path,str(i)+'.jpg'))
    i = i +1

# %%
os.rename(os.path.join(path,filename), os.path.join(path,str(i)+'.jpg'))

# %%
import os
import cv2
directory=r"C:\Users\malini.d\Desktop\Tanveer\images\pdftoimage"


for img in os.listdir(directory):
    print(img)

    ii = cv2.imread(directory+img)
    im_resized = cv2.resize(ii,(1080,300))

cv2.imwrite(img,im_resized)
cv2.imshow("Show by CV2",img)
cv2.waitKey(5)
# Out:
# 0_1.pdf.jpg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-67699efd346e> in <module>
#       8
#       9     ii = cv2.imread(directory+img)
# ---> 10     im_resized = cv2.resize(ii,('300','300'))
#      11
#      12 cv2.imwrite(img,im_resized)
#
# TypeError: an integer is required (got type str)
